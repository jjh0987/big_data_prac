# %%
import pandas as pd

# %%
numeric = pd.read_csv('/Users/junho/Downloads/naver_1year (1).csv')

# %%
numeric
# Out:
#            date       나스닥      코스피     코스닥       기관합계매수량       기타법인매수량  \
# 0    2021-05-25  13657.17  3171.32  962.07  3.717644e+10 -3.254900e+07
# 1    2021-05-26  13738.00  3168.43  966.06  4.790684e+10 -3.788020e+08
# 2    2021-05-27  13736.28  3165.51  974.08  9.866640e+09  9.310600e+07
# 3    2021-05-28  13748.74  3188.73  977.46  1.966990e+09  1.733319e+09
# 4    2021-05-29  13748.74  3188.73  977.46  1.966990e+09  1.733319e+09
# ..          ...       ...      ...     ...           ...           ...
# 365  2022-05-25  11434.74  2617.22  872.69  9.309665e+09  8.966875e+08
# 366  2022-05-26  11740.65  2612.45  871.43 -3.653108e+09 -5.994050e+07
# 367  2022-05-27  12131.13  2638.05  873.97  5.416242e+09  6.267880e+08
# 368  2022-05-28  12131.13  2638.05  873.97  5.416242e+09  6.267880e+08
# 369  2022-05-29  12131.13  2638.05  873.97  5.416242e+09  6.267880e+08
#
#             개인매수량      외국인합계매수량        종가   등락률       거래량     전일비    score1  \
# ...

# %%
df = numeric
numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      370 non-null    object
#  1   나스닥       370 non-null    float64
#  2   코스피       370 non-null    float64
#  3   코스닥       370 non-null    float64
#  4   기관합계매수량   370 non-null    float64
#  5   기타법인매수량   370 non-null    float64
#  6   개인매수량     370 non-null    float64
#  7   외국인합계매수량  370 non-null    float64
#  8   종가        370 non-null    float64
#  9   등락률       370 non-null    float64
#  10  거래량       370 non-null    float64
#  11  전일비       370 non-null    float64
#  12  score1    370 non-null    float64
#  13  score2    370 non-null    float64
#  14  score3    370 non-null    float64
#  15  변동금리      370 non-null    float64
#  16  vix       370 non-null    float64
# dtypes: float64(16), object(1)
# memory usage: 49.3+ KB

# %%
from pymongo import MongoClient
my_client = MongoClient('mongodb://localhost:27017')
mydb = my_client['final_project']
mycol = mydb['basic_numeric_naver']

# %%
for i in range(len(numeric)-1):
    mycol.insert_one({'date':df.loc[i,'date'],'vix':df.loc[i,'vix'],'등락률':round(df.loc[i,'등락률'],2),
                      '금리':df.loc[i,'변동금리'],'기관':df.loc[i,'기관합계매수량'],'개인':df.loc[i,'개인매수량'],
                      '외국인':df.loc[i,'외국인합계매수량'],'score1': df.loc[i,'score1'],'score2': df.loc[i,'score2'], 'score3': df.loc[i,'score3']})
