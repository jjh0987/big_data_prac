# %%
# 4/25 기준
from transformers import pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
qa = pipeline("question-answering")
sentiment = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
# 2022-04-29 13:59:36.957692: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# All model checkpoint layers were used when initializing TFDistilBertForQuestionAnswering.
#
# All the layers of TFDistilBertForQuestionAnswering were initialized from the model checkpoint at distilbert-base-cased-distilled-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForQuestionAnswering for predictions without further training.
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Some layers from the model checkpoint at distilbert-base-uncased-finetuned-sst-2-english were not used when initializing TFDistilBertForSequenceClassification: ['dropout_19']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased-finetuned-sst-2-english and are newly initialized: ['dropout_39']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from pykrx import stock
pykrx_df = stock.get_market_ohlcv_by_date(fromdate='2021-04-25', todate='2022-04-25', ticker="035720", adjusted=False)
pykrx = pykrx_df.reset_index()

# %%
target = pd.DataFrame(pykrx.loc[:,['날짜','등락률']]).reset_index()
target = target.drop('index',axis=1)
target['날짜'] = pd.to_datetime(target['날짜'],format='%Y-%m-%d')

target
# Out:
#             날짜   등락률
# 0   2021-04-26  0.43
# 1   2021-04-27  2.97
# 2   2021-04-28 -1.65
# 3   2021-04-29 -2.09
# 4   2021-04-30 -2.99
# ..         ...   ...
# 242 2022-04-19  0.74
# 243 2022-04-20  0.00
# 244 2022-04-21 -1.58
# 245 2022-04-22 -1.71
# 246 2022-04-25 -2.50
#
# [247 rows x 2 columns]

# %%
resampled_target = pd.DataFrame(target.resample(rule='1W', on='날짜'))
resampled_target

temp = []
for i in range(len(resampled_target)):
    temp.append(resampled_target[1][i].mean())

week_rate_mean = pd.DataFrame(temp)
week_rate_mean.to_csv('/Users/junho/Desktop/data/final_csv/kakao_rate_mean')
# Out:
# /var/folders/4l/84htqxwn14n0jr_xvdc4tpbr0000gn/T/ipykernel_5728/1019736527.py:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp.append(resampled_target[1][i].mean())

# %%
week_price_mean = pd.read_csv('/Users/junho/Desktop/data/final_csv/kakao_week_mean.csv')

# %%
translated_article = list(pd.read_csv('/Users/junho/Desktop/data/final_csv/translate_article.csv')['0'])
date = list(pd.read_csv('/Users/junho/Desktop/data/final_csv/date.csv')['data'])

article_table = pd.DataFrame()
article_table['date'] = date
article_table['translated_article'] = translated_article
article_table['date'] = pd.to_datetime(article_table['date'],format='%Y-%m-%d')
article_table
# Out:
#           date                                 translated_article
# 0   2022-04-25  73 52 -weeks, including Naver, is a high -end ...
# 1   2022-04-25  -This 35 million residents of Chao Yang-gu thr...
# 2   2022-04-21  Mirae Asset Securities announced on the 21st t...
# 3   2022-04-20  Korea Investment & Securities Korea Investment...
# 4   2022-04-18  NAVER sales of 1.8 trillion won and Kakao sale...
# ..         ...                                                ...
# 437 2021-05-03  Reporter Shin Woong -su = KOSPI index is appea...
# 438 2021-05-02  KOSPI and KOSDAQ showed four consecutive days ...
# 439 2021-05-02  KOSPI and KOSDAQ showed four consecutive days ...
# 440 2021-04-29  Investors are already consulting at the Korea ...
# 441 2021-04-29  Investors are consulting at the Korea Investme...
#
# [442 rows x 2 columns]

# %%
question = 'Is the stock of the Kakao Company going up?'
data = []
for i in range(len(translated_article)):
    ans = qa(question = question, context = translated_article[i])
    senti = sentiment(ans.get('answer'))
    print(ans)
    print(senti)
    data.append(senti)
# Out:
# /Users/junho/tensorflow_macos_venv/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:708: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /Users/junho/tensorflow_macos_venv/lib/python3.8/site-packages/transformers/pipelines/question_answering.py:298: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   p_mask = np.asarray(
# {'score': 0.013775031082332134, 'start': 1190, 'end': 1216, 'answer': "Kakao Group's shareholders"}
# [{'label': 'POSITIVE', 'score': 0.9953798055648804}]
# {'score': 0.016402196139097214, 'start': 381, 'end': 386, 'answer': 'empty'}
# [{'label': 'NEGATIVE', 'score': 0.9997498393058777}]
# {'score': 0.007096478249877691, 'start': 124, 'end': 176, 'answer': 'The stocks listed this time are 38 index -type calls'}
# [{'label': 'NEGATIVE', 'score': 0.9953208565711975}]
# {'score': 0.4683855473995209, 'start': 1146, 'end': 1173, 'answer': 'KakaoTalk channel True ELW.'}
# [{'label': 'POSITIVE', 'score': 0.968518853187561}]
# {'score': 0.3051234483718872, 'start': 2276, 'end': 2287, 'answer': '150,000 won'}
# [{'label': 'POSITIVE', 'score': 0.9996310472488403}]
# {'score': 0.17509329319000244, 'start': 2813, 'end': 2842, 'answer': 'Kakao stock 288.3 billion won'}
# [{'label': 'POSITIVE', 'score': 0.9871339201927185}]
# {'score': 0.058320216834545135, 'start': 2162, 'end': 2194, 'answer': 'the stock can be fully rebounded'}
# [{'label': 'POSITIVE', 'score': 0.9885750412940979}]
# {'score': 0.14116156101226807, 'start': 196, 'end': 272, 'answer': 'The DP stock prospects were positive, and the target price was not suggested'}
# [{'label': 'NEGATIVE', 'score': 0.9869634509086609}]
# {'score': 0.43189480900764465, 'start': 777, 'end': 790, 'answer': 'fell together'}
# [{'label': 'NEGATIVE', 'score': 0.999622106552124}]
# {'score': 0.2350740283727646, 'start': 237, 'end': 273, 'answer': 'the proper stock price is 36,400 won'}
# [{'label': 'POSITIVE', 'score': 0.9433397054672241}]
# {'score': 0.04755037650465965, 'start': 1443, 'end': 1495, 'answer': 'there were many negative prospects for growth stocks'}
# [{'label': 'NEGATIVE', 'score': 0.9984697699546814}]
# {'score': 0.06959094107151031, 'start': 1887, 'end': 1928, 'answer': 'many negative prospects for growth stocks'}
# [{'label': 'NEGATIVE', 'score': 0.9991377592086792}]
# {'score': 0.1462542861700058, 'start': 2982, 'end': 3009, 'answer': "It's not a problem to go up"}
# [{'label': 'POSITIVE', 'score': 0.9971799850463867}]
# {'score': 0.40939798951148987, 'start': 117, 'end': 180, 'answer': "the company's purchase and target stocks maintained 110,000 won"}
# [{'label': 'POSITIVE', 'score': 0.9539974331855774}]
# {'score': 0.4229219853878021, 'start': 1173, 'end': 1196, 'answer': 'The stock price dropped'}
# [{'label': 'NEGATIVE', 'score': 0.9986131191253662}]
# {'score': 0.12555672228336334, 'start': 2931, 'end': 2976, 'answer': 'it was tied up as an undervalued growth stock'}
# [{'label': 'NEGATIVE', 'score': 0.9934206604957581}]
# {'score': 0.02850109525024891, 'start': 2491, 'end': 2544, 'answer': 'The two are known to have a 18.5%stake in the opening'}
# [{'label': 'POSITIVE', 'score': 0.7629033923149109}]
# {'score': 0.09730447083711624, 'start': 317, 'end': 356, 'answer': 'It was ranked 8th in the virtual assets'}
# [{'label': 'POSITIVE', 'score': 0.9254940748214722}]
# {'score': 0.15057727694511414, 'start': 151, 'end': 183, 'answer': 'the proper stock offers 8900 won'}
# [{'label': 'POSITIVE', 'score': 0.9979070425033569}]
# {'score': 0.03830218315124512, 'start': 1096, 'end': 1149, 'answer': 'Domestic stocks will also show differentiated markets'}
# [{'label': 'POSITIVE', 'score': 0.9684337377548218}]
# {'score': 0.029528241604566574, 'start': 135, 'end': 186, 'answer': 'net buying tax on companies with earnings consensus'}
# [{'label': 'NEGATIVE', 'score': 0.8993615508079529}]
# {'score': 0.033518049865961075, 'start': 11, 'end': 65, 'answer': "a total of six shares of the 5th shareholders 'meeting"}
# [{'label': 'POSITIVE', 'score': 0.7211430072784424}]
# {'score': 0.12380476295948029, 'start': 2124, 'end': 2154, 'answer': 'the stock market has increased'}
# [{'label': 'POSITIVE', 'score': 0.9984906911849976}]
# {'score': 0.175191730260849, 'start': 2273, 'end': 2303, 'answer': 'the stock market has increased'}
# [{'label': 'POSITIVE', 'score': 0.9984906911849976}]
# {'score': 0.409015029668808, 'start': 1781, 'end': 1817, 'answer': 'the company also restricted the sale'}
# [{'label': 'NEGATIVE', 'score': 0.9986346364021301}]
# {'score': 0.0367744006216526, 'start': 428, 'end': 449, 'answer': 'stocks from the 31st.'}
# [{'label': 'NEGATIVE', 'score': 0.9761137962341309}]
# {'score': 0.4660654664039612, 'start': 1682, 'end': 1718, 'answer': 'the company also restricted the sale'}
# [{'label': 'NEGATIVE', 'score': 0.9986346364021301}]
# {'score': 0.2984907329082489, 'start': 2315, 'end': 2332, 'answer': 'Kakao Bank -4.36%'}
# [{'label': 'POSITIVE', 'score': 0.9575666189193726}]
# {'score': 0.16907404363155365, 'start': 0, 'end': 32, 'answer': 'Stock prices have been rebounded'}
# [{'label': 'POSITIVE', 'score': 0.7669179439544678}]
# {'score': 0.1803268939256668, 'start': 202, 'end': 234, 'answer': 'the stock price is missing a lot'}
# [{'label': 'NEGATIVE', 'score': 0.9997636675834656}]
# {'score': 0.3828824460506439, 'start': 3263, 'end': 3287, 'answer': 'dividends are decreasing'}
# [{'label': 'NEGATIVE', 'score': 0.9974766373634338}]
# {'score': 0.030648430809378624, 'start': 125, 'end': 166, 'answer': 'Large stocks will not be rapidly reversed'}
# [{'label': 'POSITIVE', 'score': 0.9878208041191101}]
# {'score': 0.5708343982696533, 'start': 4028, 'end': 4088, 'answer': 'the stocks that are below the public offering price come out'}
# [{'label': 'NEGATIVE', 'score': 0.9963185787200928}]
# {'score': 0.4352313280105591, 'start': 4305, 'end': 4365, 'answer': 'the stocks that are below the public offering price come out'}
# [{'label': 'NEGATIVE', 'score': 0.9963185787200928}]
# {'score': 0.21593332290649414, 'start': 1064, 'end': 1091, 'answer': 'KakaoTalk channel True ELW.'}
# [{'label': 'POSITIVE', 'score': 0.968518853187561}]
# {'score': 0.014355427585542202, 'start': 297, 'end': 338, 'answer': 'there was no specific decision at present'}
# [{'label': 'NEGATIVE', 'score': 0.998620867729187}]
# {'score': 0.24591392278671265, 'start': 2283, 'end': 2325, 'answer': "Kakao and Naver's stock prices also surged"}
# [{'label': 'POSITIVE', 'score': 0.9985045194625854}]
# {'score': 0.046590521931648254, 'start': 103, 'end': 144, 'answer': 'the stock price of NAVER and Kakao surged'}
# [{'label': 'POSITIVE', 'score': 0.9886386394500732}]
# {'score': 0.402931272983551, 'start': 395, 'end': 415, 'answer': 'fell the most to 20%'}
# [{'label': 'NEGATIVE', 'score': 0.9997020363807678}]
# {'score': 0.25245290994644165, 'start': 214, 'end': 249, 'answer': 'the proper stock offered 11,500 won'}
# [{'label': 'POSITIVE', 'score': 0.9945675134658813}]
# {'score': 0.08035442233085632, 'start': 835, 'end': 863, 'answer': 'the stock price fell rapidly'}
# [{'label': 'NEGATIVE', 'score': 0.999692440032959}]
# {'score': 0.011646204628050327, 'start': 252, 'end': 294, 'answer': 'fallen enough to have a 52 -week low price'}
# [{'label': 'NEGATIVE', 'score': 0.9997292160987854}]
# {'score': 0.007388546597212553, 'start': 677, 'end': 711, 'answer': 'is up to the minority shareholders'}
# [{'label': 'POSITIVE', 'score': 0.9995545744895935}]
# {'score': 0.0282478928565979, 'start': 2515, 'end': 2575, 'answer': "The CAC is also discussed in the Kakao subsidiary's business"}
# [{'label': 'POSITIVE', 'score': 0.8603209853172302}]
# {'score': 0.044375933706760406, 'start': 561, 'end': 602, 'answer': 'Kakao shares were 180,000 won in the past'}
# [{'label': 'NEGATIVE', 'score': 0.8176258206367493}]
# {'score': 0.07203754782676697, 'start': 781, 'end': 818, 'answer': 'Samsung SDI, Kakao, and Kia closed up'}
# [{'label': 'NEGATIVE', 'score': 0.9420099258422852}]
# {'score': 0.010084500536322594, 'start': 591, 'end': 633, 'answer': 'Most of the market cap is also on the rise'}
# [{'label': 'POSITIVE', 'score': 0.9943034648895264}]
# {'score': 0.06336455792188644, 'start': 2592, 'end': 2629, 'answer': 'the global stock market has increased'}
# [{'label': 'POSITIVE', 'score': 0.9987315535545349}]
# {'score': 0.13296978175640106, 'start': 93, 'end': 125, 'answer': 'It is heating up in incineration'}
# [{'label': 'NEGATIVE', 'score': 0.9956138134002686}]
# {'score': 0.2947878837585449, 'start': 303, 'end': 369, 'answer': 'Kakao shares are willing to manage the target price of the company'}
# [{'label': 'POSITIVE', 'score': 0.9922601580619812}]
# {'score': 0.10490896552801132, 'start': 1045, 'end': 1072, 'answer': 'reached the national stocks'}
# [{'label': 'POSITIVE', 'score': 0.9980660080909729}]
# {'score': 0.008998884819447994, 'start': 150, 'end': 202, 'answer': 'The stocks listed this time are 58 index -type calls'}
# [{'label': 'NEGATIVE', 'score': 0.9968652129173279}]
# {'score': 0.029674377292394638, 'start': 4148, 'end': 4190, 'answer': 'We will eliminate the problem of platforms'}
# [{'label': 'POSITIVE', 'score': 0.8592580556869507}]
# {'score': 0.016667727380990982, 'start': 4276, 'end': 4318, 'answer': 'We will eliminate the problem of platforms'}
# [{'label': 'POSITIVE', 'score': 0.8592580556869507}]
# {'score': 0.006587843876332045, 'start': 724, 'end': 741, 'answer': 'It is in progress'}
# [{'label': 'POSITIVE', 'score': 0.9994015693664551}]
# {'score': 0.07252327352762222, 'start': 3107, 'end': 3154, 'answer': 'the third place is Kakao Games 1606 billion won'}
# [{'label': 'POSITIVE', 'score': 0.9543678164482117}]
# {'score': 0.3628356158733368, 'start': 74, 'end': 135, 'answer': 'the company is accelerating the departure of the stock market'}
# [{'label': 'NEGATIVE', 'score': 0.9982473850250244}]
# {'score': 0.02188795432448387, 'start': 3239, 'end': 3295, 'answer': 'The connection with KakaoTalk will also be strengthened.'}
# [{'label': 'POSITIVE', 'score': 0.9995267391204834}]
# {'score': 0.3955070972442627, 'start': 2258, 'end': 2268, 'answer': '90,000 won'}
# [{'label': 'POSITIVE', 'score': 0.9996781349182129}]
# {'score': 0.027883294969797134, 'start': 2316, 'end': 2341, 'answer': 'has returned to its place'}
# [{'label': 'POSITIVE', 'score': 0.9933766722679138}]
# {'score': 0.009364966303110123, 'start': 907, 'end': 916, 'answer': 'ROE 14.2%'}
# [{'label': 'NEGATIVE', 'score': 0.9699137210845947}]
# {'score': 0.05094590038061142, 'start': 1305, 'end': 1342, 'answer': 'The stock does not explain everything'}
# [{'label': 'NEGATIVE', 'score': 0.9997890591621399}]
# {'score': 0.05337410792708397, 'start': 267, 'end': 307, 'answer': 'half half a bad news in Korea and abroad'}
# [{'label': 'NEGATIVE', 'score': 0.999136745929718}]
# {'score': 0.150538831949234, 'start': 1410, 'end': 1427, 'answer': 'continued to fall'}
# [{'label': 'NEGATIVE', 'score': 0.998077392578125}]
# {'score': 0.014627916738390923, 'start': 330, 'end': 358, 'answer': '11.74% from the previous day'}
# [{'label': 'POSITIVE', 'score': 0.9863894581794739}]
# {'score': 0.16740618646144867, 'start': 195, 'end': 257, 'answer': 'Investment opinions and target prices have not been presented.'}
# [{'label': 'NEGATIVE', 'score': 0.9924607872962952}]
# {'score': 0.0202080886811018, 'start': 2239, 'end': 2270, 'answer': 'rising to 6.83%on the next day.'}
# [{'label': 'POSITIVE', 'score': 0.9880620241165161}]
# {'score': 0.12453210353851318, 'start': 652, 'end': 715, 'answer': 'In January, there is no plus revenue among the KRX sector index'}
# [{'label': 'NEGATIVE', 'score': 0.9993948936462402}]
# {'score': 0.11909695714712143, 'start': 1645, 'end': 1692, 'answer': 'In January, stock prices fell by more than 28%.'}
# [{'label': 'NEGATIVE', 'score': 0.9994945526123047}]
# {'score': 0.06988245248794556, 'start': 951, 'end': 1024, 'answer': 'The agency nets 65.7 billion won worth of stocks in the securities market'}
# [{'label': 'POSITIVE', 'score': 0.9849403500556946}]
# {'score': 0.38106769323349, 'start': 5977, 'end': 6022, 'answer': 'It will also burden the domestic stock market'}
# [{'label': 'NEGATIVE', 'score': 0.9983003735542297}]
# {'score': 0.42264682054519653, 'start': 2296, 'end': 2336, 'answer': 'Some stocks have fallen due to incidents'}
# [{'label': 'NEGATIVE', 'score': 0.999665379524231}]
# {'score': 0.12370368093252182, 'start': 2295, 'end': 2356, 'answer': 'the stocks held by individuals may not go up from the rebound'}
# [{'label': 'NEGATIVE', 'score': 0.9996969699859619}]
# {'score': 0.06814108043909073, 'start': 985, 'end': 1027, 'answer': 'fell so that the panic trend was unfolded.'}
# [{'label': 'NEGATIVE', 'score': 0.9986335635185242}]
# {'score': 0.15158934891223907, 'start': 1388, 'end': 1423, 'answer': 'stock prices are below expectations'}
# [{'label': 'NEGATIVE', 'score': 0.9622541069984436}]
# {'score': 0.3967784345149994, 'start': 632, 'end': 703, 'answer': "Most of the market capitalization's top -ranking stock price is falling"}
# [{'label': 'NEGATIVE', 'score': 0.9997451901435852}]
# {'score': 0.022847691550850868, 'start': 205, 'end': 250, 'answer': 'more than 114 trillion won in domestic stocks'}
# [{'label': 'POSITIVE', 'score': 0.9955729246139526}]
# {'score': 0.38251081109046936, 'start': 2423, 'end': 2449, 'answer': 'recaptured the third place'}
# [{'label': 'POSITIVE', 'score': 0.9970530271530151}]
# {'score': 0.003273364156484604, 'start': 2329, 'end': 2345, 'answer': 'Kakao affiliates'}
# [{'label': 'POSITIVE', 'score': 0.9733105301856995}]
# {'score': 0.2929370105266571, 'start': 952, 'end': 1011, 'answer': 'Kakao Group stock investors are getting into falling stocks'}
# [{'label': 'NEGATIVE', 'score': 0.9989987015724182}]
# {'score': 0.2852320075035095, 'start': 1478, 'end': 1518, 'answer': "fell more than 45% from last year's peak"}
# [{'label': 'NEGATIVE', 'score': 0.9991611242294312}]
# {'score': 0.01726185344159603, 'start': 0, 'end': 30, 'answer': 'Equity is equal to 1 ~ 2 weeks'}
# [{'label': 'POSITIVE', 'score': 0.8084126114845276}]
# {'score': 0.020050354301929474, 'start': 0, 'end': 64, 'answer': 'The balance of horse barrels also increased by 1.37 trillion won'}
# [{'label': 'POSITIVE', 'score': 0.9014794826507568}]
# {'score': 0.08241306245326996, 'start': 1273, 'end': 1325, 'answer': 'the stock is expected to rank second beyond SK Hynix'}
# [{'label': 'POSITIVE', 'score': 0.8381935358047485}]
# {'score': 0.14066237211227417, 'start': 1964, 'end': 2033, 'answer': 'Kakao is a group of large companies ranked 18th in the business world'}
# [{'label': 'POSITIVE', 'score': 0.9733746647834778}]
# {'score': 0.06005806475877762, 'start': 53, 'end': 103, 'answer': 'All four groups, including Kakao, have fallen down'}
# [{'label': 'NEGATIVE', 'score': 0.9997126460075378}]
# {'score': 0.03204755112528801, 'start': 2368, 'end': 2401, 'answer': 'If the stock price rises only 32%'}
# [{'label': 'NEGATIVE', 'score': 0.9943510293960571}]
# {'score': 0.06005806475877762, 'start': 53, 'end': 103, 'answer': 'All four groups, including Kakao, have fallen down'}
# [{'label': 'NEGATIVE', 'score': 0.9997126460075378}]
# {'score': 0.09738334268331528, 'start': 607, 'end': 671, 'answer': 'The news of this news has continued to strengthen related stocks'}
# [{'label': 'POSITIVE', 'score': 0.9989953637123108}]
# {'score': 0.04143085703253746, 'start': 1016, 'end': 1061, 'answer': 'Kakao Bank, which has been the largest margin'}
# [{'label': 'POSITIVE', 'score': 0.9904196858406067}]
# {'score': 0.11324194073677063, 'start': 1412, 'end': 1474, 'answer': 'There is no public offering in the history of the stock market'}
# [{'label': 'NEGATIVE', 'score': 0.9992726445198059}]
# {'score': 0.515194833278656, 'start': 2789, 'end': 2833, 'answer': 'Kakao, Naver, and Kakao Bank also ranked top'}
# [{'label': 'POSITIVE', 'score': 0.9991170763969421}]
# {'score': 0.016394492238759995, 'start': 2562, 'end': 2595, 'answer': 'stock prices have recently fallen'}
# [{'label': 'NEGATIVE', 'score': 0.9997077584266663}]
# {'score': 0.4437338709831238, 'start': 1734, 'end': 1763, 'answer': 'All of the top 10 stocks fell'}
# [{'label': 'NEGATIVE', 'score': 0.999701201915741}]
# {'score': 0.0183357372879982, 'start': 1001, 'end': 1038, 'answer': 'the consensus is expected to be lower'}
# [{'label': 'NEGATIVE', 'score': 0.9996306896209717}]
# {'score': 0.01707916520535946, 'start': 474, 'end': 479, 'answer': 'lower'}
# [{'label': 'NEGATIVE', 'score': 0.9995342493057251}]
# {'score': 0.39432743191719055, 'start': 1176, 'end': 1200, 'answer': 'Kakao shares have fallen'}
# [{'label': 'NEGATIVE', 'score': 0.9997346997261047}]
# {'score': 0.05333158001303673, 'start': 660, 'end': 676, 'answer': '23375,000 shares'}
# [{'label': 'POSITIVE', 'score': 0.8636081218719482}]
# {'score': 0.038795847445726395, 'start': 586, 'end': 670, 'answer': 'the number of shares of the institutional allocation competition is 23375,000 shares'}
# [{'label': 'NEGATIVE', 'score': 0.864870548248291}]
# {'score': 0.267928808927536, 'start': 1207, 'end': 1245, 'answer': "the vice chairman's remarks have begun"}
# [{'label': 'POSITIVE', 'score': 0.9679719805717468}]
# {'score': 0.1862660050392151, 'start': 659, 'end': 689, 'answer': 'fell 18.27%in six trading days'}
# [{'label': 'NEGATIVE', 'score': 0.999548614025116}]
# {'score': 0.04902120307087898, 'start': 1782, 'end': 1848, 'answer': "K -Bank's listing and technical coordination have been influenced."}
# [{'label': 'POSITIVE', 'score': 0.9971334934234619}]
# {'score': 0.17455439269542694, 'start': 197, 'end': 229, 'answer': 'The stock price has risen by 16%'}
# [{'label': 'POSITIVE', 'score': 0.9845579266548157}]
# {'score': 0.050971031188964844, 'start': 1998, 'end': 2041, 'answer': 'The price drops 3.40% from the previous day'}
# [{'label': 'NEGATIVE', 'score': 0.9993165731430054}]
# {'score': 0.4906260371208191, 'start': 2449, 'end': 2523, 'answer': 'the company is speeding up its global market by acquiring global companies'}
# [{'label': 'POSITIVE', 'score': 0.9976309537887573}]
# {'score': 0.11269006133079529, 'start': 1190, 'end': 1210, 'answer': 'KOSDAQ dropped 3.75%'}
# [{'label': 'NEGATIVE', 'score': 0.998345136642456}]
# {'score': 0.05796874314546585, 'start': 1157, 'end': 1163, 'answer': 'rising'}
# [{'label': 'POSITIVE', 'score': 0.9995211362838745}]
# {'score': 0.18916070461273193, 'start': 1551, 'end': 1579, 'answer': 'the stock price will rebound'}
# [{'label': 'POSITIVE', 'score': 0.9987700581550598}]
# {'score': 0.030712468549609184, 'start': 1047, 'end': 1068, 'answer': 'situation is not good'}
# [{'label': 'NEGATIVE', 'score': 0.9997870326042175}]
# {'score': 0.33881351351737976, 'start': 3603, 'end': 3629, 'answer': 'the stock price has slowed'}
# [{'label': 'NEGATIVE', 'score': 0.9993390440940857}]
# {'score': 0.15706419944763184, 'start': 3755, 'end': 3781, 'answer': 'the stock price has slowed'}
# [{'label': 'NEGATIVE', 'score': 0.9993390440940857}]
# {'score': 0.027517950162291527, 'start': 979, 'end': 996, 'answer': '#Nft #Kakao Games'}
# [{'label': 'NEGATIVE', 'score': 0.5040519833564758}]
# {'score': 0.016204699873924255, 'start': 2445, 'end': 2516, 'answer': 'The number of public stocks assigned to individuals increased to 20%30%'}
# [{'label': 'NEGATIVE', 'score': 0.9358956813812256}]
# {'score': 0.01852094568312168, 'start': 2485, 'end': 2533, 'answer': 'the stock investment craze caused by KOSPI rises'}
# [{'label': 'NEGATIVE', 'score': 0.9857418537139893}]
# {'score': 0.015528733842074871, 'start': 480, 'end': 538, 'answer': '2021 DPS is expected to exceed 2000 won for the first time'}
# [{'label': 'POSITIVE', 'score': 0.9951819777488708}]
# {'score': 0.23560276627540588, 'start': 2305, 'end': 2340, 'answer': 'stock prices can also vary by stock'}
# [{'label': 'NEGATIVE', 'score': 0.9332087635993958}]
# {'score': 0.029960326850414276, 'start': 401, 'end': 432, 'answer': 'largest number of listed stocks'}
# [{'label': 'POSITIVE', 'score': 0.9973920583724976}]
# {'score': 0.031660400331020355, 'start': 242, 'end': 287, 'answer': 'individual investors entered the stock market'}
# [{'label': 'POSITIVE', 'score': 0.9495775699615479}]
# {'score': 0.0039153750985860825, 'start': 47, 'end': 61, 'answer': 'Neptune stocks'}
# [{'label': 'POSITIVE', 'score': 0.510702908039093}]
# {'score': 0.007704265881329775, 'start': 1031, 'end': 1079, 'answer': 'It is focusing on the mobility business division'}
# [{'label': 'POSITIVE', 'score': 0.9605838656425476}]
# {'score': 0.0029901540838181973, 'start': 128, 'end': 168, 'answer': 'it has invested more than 1 trillion won'}
# [{'label': 'POSITIVE', 'score': 0.9969683289527893}]
# {'score': 0.0627836361527443, 'start': 3343, 'end': 3374, 'answer': 'ranked first in the competition'}
# [{'label': 'POSITIVE', 'score': 0.9995291233062744}]
# {'score': 0.06783164292573929, 'start': 1599, 'end': 1602, 'answer': '50%'}
# [{'label': 'POSITIVE', 'score': 0.9973556995391846}]
# {'score': 0.22734084725379944, 'start': 79, 'end': 107, 'answer': 'The stock yield was not good'}
# [{'label': 'NEGATIVE', 'score': 0.999748170375824}]
# {'score': 0.05648583918809891, 'start': 1524, 'end': 1577, 'answer': "investors' interest in overseas markets is increasing"}
# [{'label': 'POSITIVE', 'score': 0.9981498718261719}]
# {'score': 0.11364491283893585, 'start': 3479, 'end': 3521, 'answer': 'companies with high operating profit rates'}
# [{'label': 'POSITIVE', 'score': 0.9784181714057922}]
# {'score': 0.11445867270231247, 'start': 3742, 'end': 3822, 'answer': 'the largest earnings stocks can serve as a leading stock in the earnings season.'}
# [{'label': 'POSITIVE', 'score': 0.9940699338912964}]
# {'score': 0.017445582896471024, 'start': 2221, 'end': 2307, 'answer': 'the financial company should be able to listen to the details of the important matters'}
# [{'label': 'POSITIVE', 'score': 0.9963762164115906}]
# {'score': 0.07855544239282608, 'start': 1435, 'end': 1476, 'answer': "Netmarble's 3 billion won worth of stocks"}
# [{'label': 'POSITIVE', 'score': 0.9890900254249573}]
# {'score': 0.19852469861507416, 'start': 746, 'end': 750, 'answer': 'down'}
# [{'label': 'NEGATIVE', 'score': 0.9996820688247681}]
# {'score': 0.01527332328259945, 'start': 281, 'end': 307, 'answer': 'sales growth is stabilized'}
# [{'label': 'POSITIVE', 'score': 0.9996440410614014}]
# {'score': 0.14138400554656982, 'start': 1554, 'end': 1592, 'answer': "Kakao Bank's share price plunged 6.69%"}
# [{'label': 'NEGATIVE', 'score': 0.992031455039978}]
# {'score': 0.08825862407684326, 'start': 465, 'end': 494, 'answer': 'up 7.19% from the battlefield'}
# [{'label': 'POSITIVE', 'score': 0.9958783388137817}]
# {'score': 0.18338961899280548, 'start': 567, 'end': 595, 'answer': 'Kakao Group stocks also rose'}
# [{'label': 'POSITIVE', 'score': 0.9981216788291931}]
# {'score': 0.04700080305337906, 'start': 263, 'end': 295, 'answer': 'It has increased to trillion won'}
# [{'label': 'POSITIVE', 'score': 0.9953023195266724}]
# {'score': 0.09800098836421967, 'start': 1509, 'end': 1558, 'answer': 'As construction stocks have risen a lot this year'}
# [{'label': 'POSITIVE', 'score': 0.9966421127319336}]
# {'score': 0.09241948276758194, 'start': 967, 'end': 978, 'answer': 'have fallen'}
# [{'label': 'NEGATIVE', 'score': 0.999640703201294}]
# {'score': 0.1425693929195404, 'start': 1057, 'end': 1090, 'answer': '200 companies with high liquidity'}
# [{'label': 'POSITIVE', 'score': 0.991375744342804}]
# {'score': 0.31846916675567627, 'start': 547, 'end': 599, 'answer': 'The event of this stock option is 5,000 won per week'}
# [{'label': 'NEGATIVE', 'score': 0.968686044216156}]
# {'score': 0.3503637909889221, 'start': 1542, 'end': 1553, 'answer': 'have fallen'}
# [{'label': 'NEGATIVE', 'score': 0.999640703201294}]
# {'score': 0.29337677359580994, 'start': 1850, 'end': 1887, 'answer': 'a total of 26 stocks come in and out.'}
# [{'label': 'POSITIVE', 'score': 0.5617051720619202}]
# {'score': 0.017429573461413383, 'start': 1285, 'end': 1329, 'answer': 'The index started at 1015.23, up 1.51 points'}
# [{'label': 'NEGATIVE', 'score': 0.9760594367980957}]
# {'score': 0.116048663854599, 'start': 236, 'end': 271, 'answer': 'the proper stock offered 25,920 won'}
# [{'label': 'POSITIVE', 'score': 0.9964176416397095}]
# {'score': 0.034757401794195175, 'start': 590, 'end': 635, 'answer': 'the price was formed at 400,000 won per share'}
# [{'label': 'NEGATIVE', 'score': 0.9568371772766113}]
# {'score': 0.018099846318364143, 'start': 1331, 'end': 1383, 'answer': 'a seller released Kakao Enter stocks for 350,000 won'}
# [{'label': 'NEGATIVE', 'score': 0.9707693457603455}]
# {'score': 0.1553930789232254, 'start': 2215, 'end': 2240, 'answer': 'Kakao fell by about 15.6%'}
# [{'label': 'NEGATIVE', 'score': 0.9997077584266663}]
# {'score': 0.1840801239013672, 'start': 3096, 'end': 3125, 'answer': 'Wemade stocks are also rising'}
# [{'label': 'POSITIVE', 'score': 0.9976239800453186}]
# {'score': 0.06680531799793243, 'start': 1207, 'end': 1237, 'answer': 'These game stocks jumped 33.6%'}
# [{'label': 'NEGATIVE', 'score': 0.9739335775375366}]
# {'score': 0.09321799874305725, 'start': 1190, 'end': 1196, 'answer': 'strong'}
# [{'label': 'POSITIVE', 'score': 0.999862551689148}]
# {'score': 0.09572483599185944, 'start': 3368, 'end': 3416, 'answer': 'growth of related stocks and funds will continue'}
# [{'label': 'POSITIVE', 'score': 0.9993916749954224}]
# {'score': 0.3570798337459564, 'start': 1050, 'end': 1100, 'answer': 'the stock price of these stocks rose significantly'}
# [{'label': 'POSITIVE', 'score': 0.998477041721344}]
# {'score': 0.006184381898492575, 'start': 1359, 'end': 1444, 'answer': 'the theme -oriented stock market will continue due to the obvious absence of momentum'}
# [{'label': 'NEGATIVE', 'score': 0.9997660517692566}]
# {'score': 0.03390613943338394, 'start': 1401, 'end': 1436, 'answer': 'We have selected platform companies'}
# [{'label': 'POSITIVE', 'score': 0.9964620471000671}]
# {'score': 0.18085215985774994, 'start': 1317, 'end': 1371, 'answer': 'Foreigners and institutions buy Naver and Kakao stocks'}
# [{'label': 'POSITIVE', 'score': 0.5848625898361206}]
# {'score': 0.058627963066101074, 'start': 131, 'end': 191, 'answer': 'large game stocks have been alienated at the market industry'}
# [{'label': 'NEGATIVE', 'score': 0.9983780384063721}]
# {'score': 0.060473259538412094, 'start': 88, 'end': 92, 'answer': 'rose'}
# [{'label': 'POSITIVE', 'score': 0.9995088577270508}]
# {'score': 0.051446583122015, 'start': 73, 'end': 133, 'answer': 'large game stocks have been alienated at the market industry'}
# [{'label': 'NEGATIVE', 'score': 0.9983780384063721}]
# {'score': 0.035541944205760956, 'start': 2738, 'end': 2753, 'answer': 'it ranked No. 1'}
# [{'label': 'POSITIVE', 'score': 0.9983574748039246}]
# {'score': 0.28790006041526794, 'start': 1512, 'end': 1581, 'answer': 'If you sell stocks at this point, you have to lose significant losses'}
# [{'label': 'NEGATIVE', 'score': 0.9992712140083313}]
# {'score': 0.1183609813451767, 'start': 62, 'end': 137, 'answer': 'new listed companies have been imminent, raising concerns about the volume.'}
# [{'label': 'POSITIVE', 'score': 0.6868220567703247}]
# {'score': 0.1084154024720192, 'start': 1236, 'end': 1261, 'answer': 'raised their stock prices'}
# [{'label': 'POSITIVE', 'score': 0.9962270259857178}]
# {'score': 0.03926434740424156, 'start': 1736, 'end': 1761, 'answer': 'raised their stock prices'}
# [{'label': 'POSITIVE', 'score': 0.9962270259857178}]
# {'score': 0.028380226343870163, 'start': 96, 'end': 138, 'answer': 'Kakao Pay shares are trading at 18,500 won'}
# [{'label': 'NEGATIVE', 'score': 0.626505970954895}]
# {'score': 0.015071588568389416, 'start': 453, 'end': 475, 'answer': 'Kakao Bank equity gain'}
# [{'label': 'POSITIVE', 'score': 0.9985982775688171}]
# {'score': 0.00811858382076025, 'start': 0, 'end': 55, 'answer': 'Foreign agencies 40.5 billion won net buying net stocks'}
# [{'label': 'POSITIVE', 'score': 0.9959902167320251}]
# {'score': 0.016213947907090187, 'start': 1040, 'end': 1097, 'answer': 'large -scale stock index rose 1.24% from the previous day'}
# [{'label': 'POSITIVE', 'score': 0.972008466720581}]
# {'score': 0.33199188113212585, 'start': 142, 'end': 147, 'answer': '9.39%'}
# [{'label': 'POSITIVE', 'score': 0.9924444556236267}]
# {'score': 0.005852959584444761, 'start': 158, 'end': 195, 'answer': 'up 45.10 points from the previous day'}
# [{'label': 'POSITIVE', 'score': 0.9967114925384521}]
# {'score': 0.06784344464540482, 'start': 299, 'end': 337, 'answer': 'Kakao Games shares closed at 8,700 won'}
# [{'label': 'POSITIVE', 'score': 0.9401370882987976}]
# {'score': 0.08024831116199493, 'start': 299, 'end': 337, 'answer': 'Kakao Games shares closed at 8,700 won'}
# [{'label': 'POSITIVE', 'score': 0.9401370882987976}]
# {'score': 0.13710947334766388, 'start': 256, 'end': 286, 'answer': 'the stock prices were positive'}
# [{'label': 'POSITIVE', 'score': 0.9996851682662964}]
# {'score': 0.08513162285089493, 'start': 1245, 'end': 1309, 'answer': 'stocks are also promising to invest in financial -related stocks'}
# [{'label': 'POSITIVE', 'score': 0.9979877471923828}]
# {'score': 0.37494271993637085, 'start': 2729, 'end': 2787, 'answer': 'the stock price of these companies exceeds the performance'}
# [{'label': 'POSITIVE', 'score': 0.9522339701652527}]
# {'score': 0.026572152972221375, 'start': 1202, 'end': 1227, 'answer': 'all of them were all down'}
# [{'label': 'NEGATIVE', 'score': 0.9992514252662659}]
# {'score': 0.04728702828288078, 'start': 680, 'end': 684, 'answer': 'down'}
# [{'label': 'NEGATIVE', 'score': 0.9996820688247681}]
# {'score': 0.14111222326755524, 'start': 2027, 'end': 2068, 'answer': 'brought down the stock price of Celltrion'}
# [{'label': 'NEGATIVE', 'score': 0.9990922212600708}]
# {'score': 0.0083606643602252, 'start': 3079, 'end': 3142, 'answer': 'fell to 47.65 trillion won without maintaining 48 trillion won.'}
# [{'label': 'NEGATIVE', 'score': 0.9969538450241089}]
# {'score': 0.11964864283800125, 'start': 2152, 'end': 2228, 'answer': 'Companies with a large number of balance or short selling are likely to fall'}
# [{'label': 'NEGATIVE', 'score': 0.9997348189353943}]
# {'score': 0.17116478085517883, 'start': 2083, 'end': 2159, 'answer': 'Companies with a large number of balance or short selling are likely to fall'}
# [{'label': 'NEGATIVE', 'score': 0.9997348189353943}]
# {'score': 0.055196113884449005, 'start': 1345, 'end': 1402, 'answer': 'The four -company integrated equal quantity is 2.33 weeks'}
# [{'label': 'NEGATIVE', 'score': 0.9686881899833679}]
# {'score': 0.011709676124155521, 'start': 3587, 'end': 3632, 'answer': 'the gross profit margin will increase further'}
# [{'label': 'POSITIVE', 'score': 0.9975205063819885}]
# {'score': 0.009536292403936386, 'start': 1111, 'end': 1148, 'answer': 'assign 100%of the public stock stocks'}
# [{'label': 'POSITIVE', 'score': 0.9268564581871033}]
# {'score': 0.05874020978808403, 'start': 301, 'end': 361, 'answer': 'the target price was lowered from 190,000 won to 180,000 won'}
# [{'label': 'NEGATIVE', 'score': 0.9926712512969971}]
# {'score': 0.17707951366901398, 'start': 629, 'end': 681, 'answer': 'Kakao is falling 2.35% from the previous trading day'}
# [{'label': 'NEGATIVE', 'score': 0.9994662404060364}]
# {'score': 0.027362912893295288, 'start': 1565, 'end': 1599, 'answer': 'it will be canceled automatically.'}
# [{'label': 'NEGATIVE', 'score': 0.9989078044891357}]
# {'score': 0.08145774155855179, 'start': 1218, 'end': 1288, 'answer': 'Interest is the stock price is expected after the listing of Kakao Pay'}
# [{'label': 'NEGATIVE', 'score': 0.9827942848205566}]
# {'score': 0.1894693374633789, 'start': 3001, 'end': 3035, 'answer': 'The stock price, which was missing'}
# [{'label': 'NEGATIVE', 'score': 0.9996562004089355}]
# {'score': 0.01566169038414955, 'start': 1362, 'end': 1395, 'answer': 'The loss belongs to the investor.'}
# [{'label': 'NEGATIVE', 'score': 0.9992848038673401}]
# {'score': 0.13585993647575378, 'start': 2500, 'end': 2527, 'answer': 'The stock price rose 12.37%'}
# [{'label': 'POSITIVE', 'score': 0.9865192770957947}]
# {'score': 0.06821075826883316, 'start': 1191, 'end': 1236, 'answer': "Kakao's stock price also closed at 12,500 won"}
# [{'label': 'NEGATIVE', 'score': 0.9802187085151672}]
# {'score': 0.13025014102458954, 'start': 2488, 'end': 2515, 'answer': 'The stock price rose 12.37%'}
# [{'label': 'POSITIVE', 'score': 0.9865192770957947}]
# {'score': 0.09279307723045349, 'start': 1810, 'end': 1832, 'answer': 'plummeted stock prices'}
# [{'label': 'NEGATIVE', 'score': 0.9996212720870972}]
# {'score': 0.004259164445102215, 'start': 579, 'end': 613, 'answer': 'up 2,900 won from the previous day'}
# [{'label': 'POSITIVE', 'score': 0.9990490078926086}]
# {'score': 0.2038554847240448, 'start': 1938, 'end': 1978, 'answer': 'Kakao closed at 12,500 won, up 4,500 won'}
# [{'label': 'POSITIVE', 'score': 0.9984534978866577}]
# {'score': 0.2841154932975769, 'start': 1192, 'end': 1219, 'answer': 'The stock price has plunged'}
# [{'label': 'NEGATIVE', 'score': 0.9936368465423584}]
# {'score': 0.13844580948352814, 'start': 1845, 'end': 1885, 'answer': 'Kakao closed at 12,500 won, up 4,500 won'}
# [{'label': 'POSITIVE', 'score': 0.9984534978866577}]
# {'score': 0.18014945089817047, 'start': 864, 'end': 903, 'answer': 'The stock price has plunged short -term'}
# [{'label': 'NEGATIVE', 'score': 0.9996477365493774}]
# {'score': 0.2846851944923401, 'start': 1414, 'end': 1453, 'answer': 'The stock price has plunged short -term'}
# [{'label': 'NEGATIVE', 'score': 0.9996477365493774}]
# {'score': 0.4393276572227478, 'start': 1194, 'end': 1206, 'answer': "I'm going up"}
# [{'label': 'POSITIVE', 'score': 0.99979168176651}]
# {'score': 0.1657012552022934, 'start': 1657, 'end': 1674, 'answer': 'it is the largest'}
# [{'label': 'POSITIVE', 'score': 0.9998236298561096}]
# {'score': 0.004285013768821955, 'start': 144, 'end': 205, 'answer': 'Investment opinions and target prices have not been presented'}
# [{'label': 'NEGATIVE', 'score': 0.9903231859207153}]
# {'score': 0.08063969016075134, 'start': 2110, 'end': 2129, 'answer': 'lower the eye level'}
# [{'label': 'NEGATIVE', 'score': 0.997296154499054}]
# {'score': 0.08075594902038574, 'start': 101, 'end': 175, 'answer': 'securities firms are also pouring out reports to lower their target prices'}
# [{'label': 'NEGATIVE', 'score': 0.999342143535614}]
# {'score': 0.08867649734020233, 'start': 638, 'end': 682, 'answer': 'Kakao Ventures recently liquidated the fund.'}
# [{'label': 'NEGATIVE', 'score': 0.9885516166687012}]
# {'score': 0.020247766748070717, 'start': 1709, 'end': 1740, 'answer': 'it is expected to be profitable'}
# [{'label': 'POSITIVE', 'score': 0.9978989362716675}]
# {'score': 0.23476874828338623, 'start': 2030, 'end': 2072, 'answer': 'Kakao fell from 163,000 won to 11,6500 won'}
# [{'label': 'NEGATIVE', 'score': 0.998364269733429}]
# {'score': 0.07660594582557678, 'start': 2626, 'end': 2668, 'answer': 'Kakao fell from 163,000 won to 11,6500 won'}
# [{'label': 'NEGATIVE', 'score': 0.998364269733429}]
# {'score': 0.31977924704551697, 'start': 2118, 'end': 2169, 'answer': 'the stock price of battery companies is also strong'}
# [{'label': 'POSITIVE', 'score': 0.9992528557777405}]
# {'score': 0.04289522022008896, 'start': 1254, 'end': 1326, 'answer': 'low -cost buying movements are appearing in that it has fallen about 25%'}
# [{'label': 'NEGATIVE', 'score': 0.9997139573097229}]
# {'score': 0.11517263203859329, 'start': 391, 'end': 454, 'answer': 'the stock price has risen three consecutive days until this day'}
# [{'label': 'NEGATIVE', 'score': 0.7823259830474854}]
# {'score': 0.09983662515878677, 'start': 1200, 'end': 1219, 'answer': 'fell 1.45%and 0.61%'}
# [{'label': 'NEGATIVE', 'score': 0.999537467956543}]
# {'score': 0.0029386207461357117, 'start': 408, 'end': 457, 'answer': '1.67%, 0.12% higher than the previous trading day'}
# [{'label': 'POSITIVE', 'score': 0.9945740103721619}]
# {'score': 0.13724522292613983, 'start': 4227, 'end': 4259, 'answer': 'the stock price has risen by 80%'}
# [{'label': 'POSITIVE', 'score': 0.9922338724136353}]
# {'score': 0.012061560526490211, 'start': 242, 'end': 296, 'answer': "Kakao's stock price has closed only seven trading days"}
# [{'label': 'NEGATIVE', 'score': 0.9991359114646912}]
# {'score': 0.0017109483014792204, 'start': 905, 'end': 995, 'answer': 'strong stock price rising and slightly adjustment process immediately after the superheat.'}
# [{'label': 'POSITIVE', 'score': 0.9533029198646545}]
# {'score': 0.05156175047159195, 'start': 1747, 'end': 1813, 'answer': 'The researcher said that it is not easy to predict the stock price'}
# [{'label': 'NEGATIVE', 'score': 0.9996527433395386}]
# {'score': 0.0288538858294487, 'start': 3001, 'end': 3034, 'answer': 'Investorship has been up to 5,000'}
# [{'label': 'POSITIVE', 'score': 0.9826270937919617}]
# {'score': 0.3130607306957245, 'start': 247, 'end': 300, 'answer': 'Kakao, on the other hand, fell to sixth in the market'}
# [{'label': 'NEGATIVE', 'score': 0.9964832067489624}]
# {'score': 0.4012773036956787, 'start': 178, 'end': 231, 'answer': 'Kakao, on the other hand, fell to sixth in the market'}
# [{'label': 'NEGATIVE', 'score': 0.9964832067489624}]
# {'score': 0.05764874070882797, 'start': 57, 'end': 146, 'answer': 'securities firms that provide personal stock service will expand from six to 19 companies'}
# [{'label': 'POSITIVE', 'score': 0.9944217801094055}]
# {'score': 0.02659291960299015, 'start': 729, 'end': 773, 'answer': 'falling compared to the previous trading day'}
# [{'label': 'NEGATIVE', 'score': 0.9989919066429138}]
# {'score': 0.019412361085414886, 'start': 1443, 'end': 1464, 'answer': 'the effect is unknown'}
# [{'label': 'NEGATIVE', 'score': 0.9991102814674377}]
# {'score': 0.10316802561283112, 'start': 2855, 'end': 2870, 'answer': 'excessive stock'}
# [{'label': 'NEGATIVE', 'score': 0.999372661113739}]
# {'score': 0.7352657914161682, 'start': 1221, 'end': 1245, 'answer': 'stock prices are falling'}
# [{'label': 'NEGATIVE', 'score': 0.9996706247329712}]
# {'score': 0.04482954740524292, 'start': 644, 'end': 689, 'answer': "Kakao's bottom value is about 55 trillion won"}
# [{'label': 'NEGATIVE', 'score': 0.9982142448425293}]
# {'score': 0.09157449752092361, 'start': 2539, 'end': 2578, 'answer': 'the Korean stock market can be affected'}
# [{'label': 'NEGATIVE', 'score': 0.9891778230667114}]
# {'score': 0.08813383430242538, 'start': 646, 'end': 679, 'answer': 'Kakao shares closed at 12,500 won'}
# [{'label': 'POSITIVE', 'score': 0.9777753949165344}]
# {'score': 0.1490776687860489, 'start': 1420, 'end': 1475, 'answer': 'the company is unclear in the second half of this year.'}
# [{'label': 'NEGATIVE', 'score': 0.9993564486503601}]
# {'score': 0.01302618533372879, 'start': 176, 'end': 207, 'answer': 'Kakao is trading at 12,6500 won'}
# [{'label': 'POSITIVE', 'score': 0.9018588066101074}]
# {'score': 0.02087065391242504, 'start': 252, 'end': 288, 'answer': 'Kakao Bank and Kakao Games turned up'}
# [{'label': 'POSITIVE', 'score': 0.6900909543037415}]
# {'score': 0.12983940541744232, 'start': 155, 'end': 189, 'answer': 'the stock price has fallen sharply'}
# [{'label': 'NEGATIVE', 'score': 0.999708354473114}]
# {'score': 0.222707599401474, 'start': 142, 'end': 162, 'answer': 'plunged side by side'}
# [{'label': 'NEGATIVE', 'score': 0.9937272071838379}]
# {'score': 0.1300203800201416, 'start': 1809, 'end': 1841, 'answer': 'It will come to the stock market'}
# [{'label': 'POSITIVE', 'score': 0.9862229228019714}]
# {'score': 0.1328546404838562, 'start': 1812, 'end': 1844, 'answer': 'It will come to the stock market'}
# [{'label': 'POSITIVE', 'score': 0.9862229228019714}]
# {'score': 0.10885055363178253, 'start': 2543, 'end': 2608, 'answer': 'we will have to pay attention to the domestic economy value stock'}
# [{'label': 'NEGATIVE', 'score': 0.9966901540756226}]
# {'score': 0.033887431025505066, 'start': 507, 'end': 548, 'answer': 'Kakao stock price finished at 12,8500 won'}
# [{'label': 'POSITIVE', 'score': 0.6610669493675232}]
# {'score': 0.06049022451043129, 'start': 2322, 'end': 2373, 'answer': 'fell 20.37% after falling for six consecutive days.'}
# [{'label': 'NEGATIVE', 'score': 0.9995182752609253}]
# {'score': 0.32116755843162537, 'start': 779, 'end': 824, 'answer': 'fell down 2.56% and 7.22% in the stock market'}
# [{'label': 'NEGATIVE', 'score': 0.9997181296348572}]
# {'score': 0.051355279982089996, 'start': 278, 'end': 303, 'answer': 'It is a series of plunges'}
# [{'label': 'NEGATIVE', 'score': 0.9725052118301392}]
# {'score': 0.18531396985054016, 'start': 0, 'end': 89, 'answer': 'Investment sentiment about secondary battery stocks is improving in domestic stock market'}
# [{'label': 'POSITIVE', 'score': 0.9973999261856079}]
# {'score': 0.204347625374794, 'start': 2280, 'end': 2319, 'answer': 'the stock price drop is also excessive.'}
# [{'label': 'NEGATIVE', 'score': 0.999159574508667}]
# {'score': 0.09626486152410507, 'start': 2162, 'end': 2201, 'answer': 'the stock price drop is also excessive.'}
# [{'label': 'NEGATIVE', 'score': 0.999159574508667}]
# {'score': 0.05150657892227173, 'start': 30, 'end': 93, 'answer': 'investor sentiment about secondary battery stocks is improving.'}
# [{'label': 'POSITIVE', 'score': 0.9981386661529541}]
# {'score': 0.028535332530736923, 'start': 1448, 'end': 1480, 'answer': 'This is 1.97%of the total stock.'}
# [{'label': 'NEGATIVE', 'score': 0.6029839515686035}]
# {'score': 0.11561324447393417, 'start': 2335, 'end': 2357, 'answer': 'did not have much fun.'}
# [{'label': 'NEGATIVE', 'score': 0.9997988343238831}]
# {'score': 0.19380560517311096, 'start': 3422, 'end': 3425, 'answer': '0.5'}
# [{'label': 'NEGATIVE', 'score': 0.9506518244743347}]
# {'score': 0.0389084592461586, 'start': 2352, 'end': 2373, 'answer': 'did not have much fun'}
# [{'label': 'NEGATIVE', 'score': 0.9997888207435608}]
# {'score': 0.2519001066684723, 'start': 230, 'end': 254, 'answer': 'NCsoft shares fell 36.4%'}
# [{'label': 'NEGATIVE', 'score': 0.9995896220207214}]
# {'score': 0.13075439631938934, 'start': 1757, 'end': 1794, 'answer': 'Kakao Bank shares closed at 8,100 won'}
# [{'label': 'POSITIVE', 'score': 0.7443609833717346}]
# {'score': 0.03142235800623894, 'start': 2715, 'end': 2769, 'answer': 'more and more people are jumping into the stock market'}
# [{'label': 'NEGATIVE', 'score': 0.8539398312568665}]
# {'score': 0.17696437239646912, 'start': 895, 'end': 924, 'answer': 'stock prices are often rising'}
# [{'label': 'POSITIVE', 'score': 0.9709879755973816}]
# {'score': 0.07181713730096817, 'start': 1313, 'end': 1363, 'answer': 'all block deals worth 1 trillion won were digested'}
# [{'label': 'NEGATIVE', 'score': 0.9958798885345459}]
# {'score': 0.1406007707118988, 'start': 133, 'end': 194, 'answer': 'Investment opinions and target prices have not been presented'}
# [{'label': 'NEGATIVE', 'score': 0.9903231859207153}]
# {'score': 0.12099739164113998, 'start': 954, 'end': 994, 'answer': 'Kakao Bank is showing a significant rise'}
# [{'label': 'POSITIVE', 'score': 0.9995005130767822}]
# {'score': 0.021549802273511887, 'start': 164, 'end': 196, 'answer': 'The stock price fell to 7430 won'}
# [{'label': 'NEGATIVE', 'score': 0.9991449117660522}]
# {'score': 0.16924096643924713, 'start': 1219, 'end': 1223, 'answer': 'rose'}
# [{'label': 'POSITIVE', 'score': 0.9995088577270508}]
# {'score': 0.012451737187802792, 'start': 1935, 'end': 2005, 'answer': 'fallen more than 4 trillion won due to the recent drop in stock prices'}
# [{'label': 'NEGATIVE', 'score': 0.9992772936820984}]
# {'score': 0.09820882230997086, 'start': 385, 'end': 420, 'answer': 'Craepon stocks closed at 49,500 won'}
# [{'label': 'NEGATIVE', 'score': 0.9322255253791809}]
# {'score': 0.15717412531375885, 'start': 1230, 'end': 1234, 'answer': 'rose'}
# [{'label': 'POSITIVE', 'score': 0.9995088577270508}]
# {'score': 0.009012198075652122, 'start': 118, 'end': 179, 'answer': 'Investment opinions and target prices have not been presented'}
# [{'label': 'NEGATIVE', 'score': 0.9903231859207153}]
# {'score': 0.05792973190546036, 'start': 246, 'end': 308, 'answer': 'small and medium -sized stocks such as Pearl Abyss have soared'}
# [{'label': 'POSITIVE', 'score': 0.9990566372871399}]
# {'score': 0.010562227107584476, 'start': 985, 'end': 1045, 'answer': 'opinions were mixed on the impact on the entire stock market'}
# [{'label': 'NEGATIVE', 'score': 0.9760230779647827}]
# {'score': 0.3049190640449524, 'start': 2328, 'end': 2362, 'answer': 'the stock price is largely divided'}
# [{'label': 'NEGATIVE', 'score': 0.9924665093421936}]
# {'score': 0.053816474974155426, 'start': 1279, 'end': 1339, 'answer': 'opinions were mixed on the impact on the entire stock market'}
# [{'label': 'NEGATIVE', 'score': 0.9760230779647827}]
# {'score': 0.3778008818626404, 'start': 1032, 'end': 1065, 'answer': 'Securities stocks are also rising'}
# [{'label': 'POSITIVE', 'score': 0.9978833794593811}]
# {'score': 0.08101542294025421, 'start': 1236, 'end': 1271, 'answer': 'third in the financial stock market'}
# [{'label': 'POSITIVE', 'score': 0.9524749517440796}]
# {'score': 0.030640725046396255, 'start': 1047, 'end': 1098, 'answer': 'Cabin is ranked third in the financial stock market'}
# [{'label': 'POSITIVE', 'score': 0.8843786120414734}]
# {'score': 0.4352221190929413, 'start': 823, 'end': 865, 'answer': 'Kakao, Kakao Bank and Naver were also weak'}
# [{'label': 'NEGATIVE', 'score': 0.9997231364250183}]
# {'score': 0.073672354221344, 'start': 1521, 'end': 1543, 'answer': 'I kept the stock price'}
# [{'label': 'POSITIVE', 'score': 0.9578337073326111}]
# {'score': 0.021363556385040283, 'start': 261, 'end': 295, 'answer': 'It is a new list of various stocks'}
# [{'label': 'NEGATIVE', 'score': 0.9847761392593384}]
# {'score': 0.01024500373750925, 'start': 455, 'end': 471, 'answer': 'It has increased'}
# [{'label': 'POSITIVE', 'score': 0.9995630383491516}]
# {'score': 0.004502370487898588, 'start': 2517, 'end': 2518, 'answer': '.'}
# [{'label': 'POSITIVE', 'score': 0.9668781757354736}]
# {'score': 0.0721522867679596, 'start': 1258, 'end': 1319, 'answer': 'reduction amount is about 6.8 billion won, with 700,000 cases'}
# [{'label': 'NEGATIVE', 'score': 0.9775168895721436}]
# {'score': 0.05870490148663521, 'start': 104, 'end': 170, 'answer': 'companies are accelerating ESG management and investment worldwide'}
# [{'label': 'POSITIVE', 'score': 0.9987945556640625}]
# {'score': 0.0326673686504364, 'start': 174, 'end': 244, 'answer': 'recent stock market trends are influenced by foreign supply and demand'}
# [{'label': 'NEGATIVE', 'score': 0.9525269865989685}]
# {'score': 0.35461142659187317, 'start': 2515, 'end': 2572, 'answer': "Netmarble's share price is required to rise significantly"}
# [{'label': 'POSITIVE', 'score': 0.9976110458374023}]
# {'score': 0.05002869665622711, 'start': 185, 'end': 256, 'answer': 'recent stock market trends are influenced by foreign supply and demand.'}
# [{'label': 'NEGATIVE', 'score': 0.961970865726471}]
# {'score': 0.1243276447057724, 'start': 39, 'end': 116, 'answer': 'The stock price is slow due to the low performance of domestic game companies'}
# [{'label': 'NEGATIVE', 'score': 0.9997676014900208}]
# {'score': 0.039384037256240845, 'start': 262, 'end': 305, 'answer': 'I did not ask to buy and bury a large stock'}
# [{'label': 'NEGATIVE', 'score': 0.8118672966957092}]
# {'score': 0.5081047415733337, 'start': 1467, 'end': 1471, 'answer': 'fell'}
# [{'label': 'NEGATIVE', 'score': 0.9996529817581177}]
# {'score': 0.1414802223443985, 'start': 1952, 'end': 1996, 'answer': 'the stock price of these companies also rose'}
# [{'label': 'POSITIVE', 'score': 0.99747234582901}]
# {'score': 0.04204057529568672, 'start': 1907, 'end': 1952, 'answer': 'the stock price of these companies also rose.'}
# [{'label': 'POSITIVE', 'score': 0.9978153705596924}]
# {'score': 0.03596927598118782, 'start': 1231, 'end': 1274, 'answer': 'The index fermentation date is September 1.'}
# [{'label': 'POSITIVE', 'score': 0.6730316877365112}]
# {'score': 0.16209836304187775, 'start': 1235, 'end': 1271, 'answer': 'lower than that of the public public'}
# [{'label': 'NEGATIVE', 'score': 0.999524712562561}]
# {'score': 0.06989558041095734, 'start': 1495, 'end': 1522, 'answer': '0.08% from the previous day'}
# [{'label': 'NEGATIVE', 'score': 0.6970624327659607}]
# {'score': 0.2767825126647949, 'start': 1285, 'end': 1321, 'answer': 'lower than that of the public public'}
# ...
# [{'label': 'POSITIVE', 'score': 0.6483482122421265}]
# {'score': 0.18742907047271729, 'start': 1196, 'end': 1226, 'answer': 'The stock price is undervalued'}
# [{'label': 'NEGATIVE', 'score': 0.9925563931465149}]
# {'score': 0.07894273847341537, 'start': 201, 'end': 249, 'answer': 'The stock price soared to 7340 won in the market'}
# [{'label': 'POSITIVE', 'score': 0.9974634647369385}]
# {'score': 0.15936774015426636, 'start': 160, 'end': 230, 'answer': 'the stock prices were positive and the proper stock offered 17,000 won'}
# [{'label': 'POSITIVE', 'score': 0.997100293636322}]
# {'score': 0.005252293776720762, 'start': 508, 'end': 540, 'answer': 'The target of the sale is 28.41%'}
# [{'label': 'NEGATIVE', 'score': 0.9963709115982056}]
# {'score': 0.2169986367225647, 'start': 1267, 'end': 1326, 'answer': 'Kakao Games shares fell 5.33% from the previous trading day'}
# [{'label': 'NEGATIVE', 'score': 0.9994309544563293}]
# {'score': 0.03323420509696007, 'start': 1344, 'end': 1426, 'answer': 'the company provides opportunities to invest in companies in the pre -public stage'}
# [{'label': 'POSITIVE', 'score': 0.999649167060852}]
# {'score': 0.017176490277051926, 'start': 774, 'end': 808, 'answer': 'Operating profit was lowered 18.2%'}
# [{'label': 'NEGATIVE', 'score': 0.9989157915115356}]
# {'score': 0.12648910284042358, 'start': 448, 'end': 486, 'answer': 'Odin Up was second in Kakem and KOSDAQ'}
# [{'label': 'POSITIVE', 'score': 0.9671121835708618}]
# {'score': 0.0323718897998333, 'start': 2057, 'end': 2132, 'answer': 'the fight over the second place is expected to continue for the time being.'}
# [{'label': 'NEGATIVE', 'score': 0.707666277885437}]
# {'score': 0.0732131078839302, 'start': 2328, 'end': 2364, 'answer': "MTS's utilization has also increased"}
# [{'label': 'POSITIVE', 'score': 0.9955516457557678}]
# {'score': 0.055937230587005615, 'start': 2299, 'end': 2335, 'answer': "MTS's utilization has also increased"}
# [{'label': 'POSITIVE', 'score': 0.9955516457557678}]
# {'score': 0.34044313430786133, 'start': 235, 'end': 288, 'answer': 'Securities firms are also raising their target prices'}
# [{'label': 'POSITIVE', 'score': 0.9948117733001709}]
# {'score': 0.28090646862983704, 'start': 114, 'end': 167, 'answer': 'Securities firms are also raising their target prices'}
# [{'label': 'POSITIVE', 'score': 0.9948117733001709}]
# {'score': 0.023016251623630524, 'start': 3237, 'end': 3314, 'answer': 'there is a growing concern for a red light in the success of the subscription'}
# [{'label': 'POSITIVE', 'score': 0.9871377944946289}]
# {'score': 0.08812476694583893, 'start': 2385, 'end': 2394, 'answer': 'W14.1trn.'}
# [{'label': 'NEGATIVE', 'score': 0.9770061373710632}]
# {'score': 0.024905459955334663, 'start': 3234, 'end': 3311, 'answer': 'there is a growing concern for a red light in the success of the subscription'}
# [{'label': 'POSITIVE', 'score': 0.9871377944946289}]
# {'score': 0.02228979393839836, 'start': 161, 'end': 209, 'answer': 'Kakao Games shares exceeded 70,000 won per share'}
# [{'label': 'NEGATIVE', 'score': 0.8406554460525513}]
# {'score': 0.08662515133619308, 'start': 2324, 'end': 2403, 'answer': 'the stock price is expected to rise in the content sector and platform business'}
# [{'label': 'POSITIVE', 'score': 0.9904125332832336}]
# {'score': 0.29591795802116394, 'start': 808, 'end': 844, 'answer': 'all of the top 10 stocks were closed'}
# [{'label': 'NEGATIVE', 'score': 0.9942863583564758}]
# {'score': 0.24364127218723297, 'start': 1186, 'end': 1190, 'answer': 'rose'}
# [{'label': 'POSITIVE', 'score': 0.9995088577270508}]
# {'score': 0.11440596729516983, 'start': 2400, 'end': 2431, 'answer': 'it has been overturned in Kakao'}
# [{'label': 'NEGATIVE', 'score': 0.987916886806488}]
# {'score': 0.14952506124973297, 'start': 2064, 'end': 2096, 'answer': 'the prospects are mixed with bio'}
# [{'label': 'NEGATIVE', 'score': 0.9938650727272034}]
# {'score': 0.223454549908638, 'start': 2014, 'end': 2046, 'answer': 'the prospects are mixed with bio'}
# [{'label': 'NEGATIVE', 'score': 0.9938650727272034}]
# {'score': 0.26965776085853577, 'start': 2065, 'end': 2116, 'answer': "the company does not refer to the company's company"}
# [{'label': 'NEGATIVE', 'score': 0.9609951972961426}]
# {'score': 0.005885500926524401, 'start': 240, 'end': 277, 'answer': 'offered a target price of 400,000 won'}
# [{'label': 'NEGATIVE', 'score': 0.6542877554893494}]
# {'score': 0.07561077922582626, 'start': 576, 'end': 614, 'answer': 'Kakao Bank issued 65.45 million shares'}
# [{'label': 'POSITIVE', 'score': 0.8633521199226379}]
# {'score': 0.08414653688669205, 'start': 162, 'end': 211, 'answer': 'stock prices have been plunging since the listing'}
# [{'label': 'NEGATIVE', 'score': 0.9890164136886597}]
# {'score': 0.48675665259361267, 'start': 1138, 'end': 1164, 'answer': 'The stock price has soared'}
# [{'label': 'POSITIVE', 'score': 0.9996635913848877}]
# {'score': 0.28362607955932617, 'start': 3882, 'end': 3914, 'answer': 'the growth stock will rise again'}
# [{'label': 'POSITIVE', 'score': 0.999313235282898}]
# {'score': 0.38461834192276, 'start': 1383, 'end': 1394, 'answer': '775 million'}
# [{'label': 'POSITIVE', 'score': 0.9938035011291504}]
# {'score': 0.12592266499996185, 'start': 284, 'end': 317, 'answer': 'I feel like something is going up'}
# [{'label': 'POSITIVE', 'score': 0.9989025592803955}]
# {'score': 0.0008471423643641174, 'start': 175, 'end': 187, 'answer': 'It came out.'}
# [{'label': 'POSITIVE', 'score': 0.9982252717018127}]
# {'score': 0.02811596170067787, 'start': 2550, 'end': 2576, 'answer': 'The stock price rose 9.38%'}
# [{'label': 'POSITIVE', 'score': 0.9767444133758545}]
# {'score': 0.0661560669541359, 'start': 1119, 'end': 1180, 'answer': 'risen more than 3 trillion won due to a surge in stock prices'}
# [{'label': 'POSITIVE', 'score': 0.9961202144622803}]
# {'score': 0.02508147992193699, 'start': 1220, 'end': 1249, 'answer': 'Ground X, a Kakao subsidiary.'}
# [{'label': 'POSITIVE', 'score': 0.6868709921836853}]
# {'score': 0.07729646563529968, 'start': 2269, 'end': 2328, 'answer': 'the competition for the stock market continues to continue.'}
# [{'label': 'POSITIVE', 'score': 0.9922466278076172}]
# {'score': 0.04220321401953697, 'start': 52, 'end': 122, 'answer': 'the interest of some stocks is to achieve the upper limit golden cross'}
# [{'label': 'POSITIVE', 'score': 0.9821010231971741}]
# {'score': 0.09875263273715973, 'start': 553, 'end': 644, 'answer': 'Hana Financial Investment has significant favorable stocks to drive additional stock prices'}
# [{'label': 'POSITIVE', 'score': 0.9993853569030762}]
# {'score': 0.11020539700984955, 'start': 624, 'end': 671, 'answer': 'The number of public shares is 1,100,230 shares'}
# [{'label': 'POSITIVE', 'score': 0.5986143350601196}]
# {'score': 0.07319458574056625, 'start': 572, 'end': 619, 'answer': 'The number of public shares is 1,100,230 shares'}
# [{'label': 'POSITIVE', 'score': 0.5986143350601196}]
# {'score': 0.0482364185154438, 'start': 1526, 'end': 1610, 'answer': 'it will be transformed into a national stock that can be easily accessible to anyone'}
# [{'label': 'POSITIVE', 'score': 0.9988069534301758}]
# {'score': 0.08915235847234726, 'start': 2603, 'end': 2633, 'answer': '13.2 won from the previous day'}
# [{'label': 'POSITIVE', 'score': 0.9994937181472778}]
# {'score': 0.02124819904565811, 'start': 751, 'end': 763, 'answer': 'KOSPI stocks'}
# [{'label': 'NEGATIVE', 'score': 0.9594378471374512}]
# {'score': 0.009730604477226734, 'start': 693, 'end': 730, 'answer': 'The market cap is 63.4819 billion won'}
# [{'label': 'POSITIVE', 'score': 0.8401201367378235}]
# {'score': 0.1570507287979126, 'start': 17, 'end': 89, 'answer': 'interest in the three domestic telecommunication companies is increasing'}
# [{'label': 'POSITIVE', 'score': 0.9977241158485413}]
# {'score': 0.10079002380371094, 'start': 1000, 'end': 1046, 'answer': "Kakao's stock price showed an unstoppable move"}
# [{'label': 'POSITIVE', 'score': 0.9913259148597717}]
# {'score': 0.105836421251297, 'start': 1423, 'end': 1480, 'answer': 'The current stock price is approaching the top of the box'}
# [{'label': 'NEGATIVE', 'score': 0.9481245875358582}]
# {'score': 0.051416780799627304, 'start': 3471, 'end': 3491, 'answer': 'predicting a line up'}
# [{'label': 'POSITIVE', 'score': 0.9943238496780396}]
# {'score': 0.04322804510593414, 'start': 1515, 'end': 1566, 'answer': 'target price was set up from 170,000 to 180,000 won'}
# [{'label': 'NEGATIVE', 'score': 0.9762411713600159}]
# {'score': 0.05485481023788452, 'start': 3514, 'end': 3572, 'answer': 'decreased by half from 1.3 trillion won to 647 billion won'}
# [{'label': 'NEGATIVE', 'score': 0.9925346374511719}]
# {'score': 0.0138204051181674, 'start': 148, 'end': 190, 'answer': 'up 1.05% from the previous day at 2:49 pm.'}
# [{'label': 'POSITIVE', 'score': 0.9848276376724243}]
# {'score': 0.08170163631439209, 'start': 1388, 'end': 1406, 'answer': '100% Melon Company'}
# [{'label': 'POSITIVE', 'score': 0.9942309856414795}]
# {'score': 0.12963250279426575, 'start': 541, 'end': 584, 'answer': "it is possible to raise Kakao's stock price"}
# [{'label': 'POSITIVE', 'score': 0.9919568300247192}]
# {'score': 0.2114955186843872, 'start': 3601, 'end': 3647, 'answer': 'There is also room for the stock price to rise'}
# [{'label': 'NEGATIVE', 'score': 0.9990308284759521}]
# {'score': 0.019845815375447273, 'start': 2772, 'end': 2808, 'answer': 'the stock price adjustment was fully'}
# [{'label': 'POSITIVE', 'score': 0.9957841038703918}]
# {'score': 0.02157939411699772, 'start': 2664, 'end': 2740, 'answer': 'the company advised that sales were improved according to the economic cycle'}
# [{'label': 'POSITIVE', 'score': 0.676420271396637}]
# {'score': 0.010555232875049114, 'start': 764, 'end': 795, 'answer': 'increased by 70%more than usual'}
# [{'label': 'POSITIVE', 'score': 0.9993785619735718}]
# {'score': 0.019874004647135735, 'start': 1422, 'end': 1492, 'answer': 'Shinhan Investment Corp. also expanded US stock free market order time'}
# [{'label': 'POSITIVE', 'score': 0.9958058595657349}]
# {'score': 0.08296793699264526, 'start': 1223, 'end': 1232, 'answer': '25%to 30%'}
# [{'label': 'POSITIVE', 'score': 0.957172691822052}]
# {'score': 0.08972717076539993, 'start': 3679, 'end': 3710, 'answer': 'Institutions also bought stocks'}
# [{'label': 'POSITIVE', 'score': 0.9740955829620361}]
# {'score': 0.03535016253590584, 'start': 3661, 'end': 3692, 'answer': 'Institutions also bought stocks'}
# [{'label': 'POSITIVE', 'score': 0.9740955829620361}]
# {'score': 0.05001054331660271, 'start': 141, 'end': 180, 'answer': 'expanded in the second half of the year'}
# [{'label': 'POSITIVE', 'score': 0.9978658556938171}]
# {'score': 0.2656819224357605, 'start': 2504, 'end': 2568, 'answer': 'the company is expected to be the largest in the current company'}
# [{'label': 'POSITIVE', 'score': 0.9984128475189209}]
# {'score': 0.02096063271164894, 'start': 132, 'end': 168, 'answer': 'SM CC shares are trading at 2410 won'}
# [{'label': 'POSITIVE', 'score': 0.7544944882392883}]
# {'score': 0.14052574336528778, 'start': 180, 'end': 185, 'answer': '3.41%'}
# [{'label': 'POSITIVE', 'score': 0.9894201755523682}]
# {'score': 0.09487766772508621, 'start': 303, 'end': 333, 'answer': "Kakao's share price rose 49.6%"}
# [{'label': 'POSITIVE', 'score': 0.9809881448745728}]
# {'score': 0.04103025421500206, 'start': 1539, 'end': 1602, 'answer': 'future stocks of companies that have turned a quarterly surplus'}
# [{'label': 'NEGATIVE', 'score': 0.7602852582931519}]
# {'score': 0.02174527943134308, 'start': 801, 'end': 819, 'answer': 'up 39.7% and 20.2%'}
# [{'label': 'POSITIVE', 'score': 0.9930030703544617}]
# {'score': 0.020194778218865395, 'start': 2510, 'end': 2527, 'answer': 'It is coming out.'}
# [{'label': 'POSITIVE', 'score': 0.9986295700073242}]
# {'score': 0.0639837235212326, 'start': 1197, 'end': 1253, 'answer': 'the ECM market is expected to be solid in the ECM market'}
# [{'label': 'POSITIVE', 'score': 0.997738242149353}]
# {'score': 0.012831033207476139, 'start': 150, 'end': 198, 'answer': 'The stocks listed this time are 45 indexed calls'}
# [{'label': 'NEGATIVE', 'score': 0.9917192459106445}]
# {'score': 0.2413170486688614, 'start': 561, 'end': 618, 'answer': 'the stock price dropped and the stock price fell 5700 won'}
# [{'label': 'NEGATIVE', 'score': 0.9995705485343933}]
# {'score': 0.1826971024274826, 'start': 2255, 'end': 2326, 'answer': 'small and medium -sized IPO companies have fallen below the stock price'}
# [{'label': 'NEGATIVE', 'score': 0.9991349577903748}]
# {'score': 0.00750715471804142, 'start': 1537, 'end': 1629, 'answer': 'maintain the best stock in the securities industry by exceeding expectations in all sectors.'}
# [{'label': 'POSITIVE', 'score': 0.9996628761291504}]
# {'score': 0.17278282344341278, 'start': 2894, 'end': 2938, 'answer': 'sold 159.1 billion won worth of stocks alone'}
# [{'label': 'POSITIVE', 'score': 0.9829187393188477}]
# {'score': 0.0024614392314106226, 'start': 169, 'end': 247, 'answer': 'The possibility of removal due to the full -fledged communication is increased'}
# [{'label': 'POSITIVE', 'score': 0.7637659311294556}]
# {'score': 0.06382273137569427, 'start': 772, 'end': 815, 'answer': 'Netmarble would have a stock price momentum'}
# [{'label': 'NEGATIVE', 'score': 0.9940383434295654}]
# {'score': 0.06930012255907059, 'start': 3201, 'end': 3264, 'answer': 'The stock will look attractive only by changing corporate sales'}
# [{'label': 'POSITIVE', 'score': 0.6650193929672241}]
# {'score': 0.24215392768383026, 'start': 3047, 'end': 3110, 'answer': 'The stock will look attractive only by changing corporate sales'}
# [{'label': 'POSITIVE', 'score': 0.6650193929672241}]
# {'score': 0.034837689250707626, 'start': 1003, 'end': 1038, 'answer': 'the stock price rose to 905,000 won'}
# [{'label': 'POSITIVE', 'score': 0.9452951550483704}]
# {'score': 0.3047635555267334, 'start': 118, 'end': 154, 'answer': 'the stock price fell by 47.77 points'}
# [{'label': 'NEGATIVE', 'score': 0.9996275901794434}]
# {'score': 0.00739564374089241, 'start': 1384, 'end': 1445, 'answer': 'it will surpass NCsoft, ranking 23rd in the securities market'}
# [{'label': 'POSITIVE', 'score': 0.9959145188331604}]
# {'score': 0.1511911302804947, 'start': 1378, 'end': 1388, 'answer': 'have risen'}
# [{'label': 'POSITIVE', 'score': 0.9995765089988708}]
# {'score': 0.07154689729213715, 'start': 1329, 'end': 1334, 'answer': 'risen'}
# [{'label': 'POSITIVE', 'score': 0.9989320635795593}]
# {'score': 0.07892017066478729, 'start': 1287, 'end': 1326, 'answer': 'the stock price is currently 15,500 won'}
# [{'label': 'POSITIVE', 'score': 0.7575342059135437}]
# {'score': 0.1614968478679657, 'start': 1256, 'end': 1281, 'answer': 'the stock price recovered'}
# [{'label': 'POSITIVE', 'score': 0.9700936079025269}]
# {'score': 0.330893337726593, 'start': 2955, 'end': 2980, 'answer': 'the stock will rise again'}
# [{'label': 'POSITIVE', 'score': 0.9990461468696594}]
# {'score': 0.17537997663021088, 'start': 1357, 'end': 1392, 'answer': 'Most of the stock prices have risen'}
# [{'label': 'POSITIVE', 'score': 0.9968804121017456}]
# {'score': 0.3614932596683502, 'start': 3136, 'end': 3161, 'answer': 'the stock will rise again'}
# [{'label': 'POSITIVE', 'score': 0.9990461468696594}]
# {'score': 0.21682755649089813, 'start': 2665, 'end': 2686, 'answer': 'falling significantly'}
# [{'label': 'NEGATIVE', 'score': 0.998033344745636}]
# {'score': 0.3432181775569916, 'start': 1488, 'end': 1547, 'answer': 'the stock price will fluctuate depending on the performance'}
# [{'label': 'NEGATIVE', 'score': 0.9985740184783936}]
# {'score': 0.3432181775569916, 'start': 1488, 'end': 1547, 'answer': 'the stock price will fluctuate depending on the performance'}
# [{'label': 'NEGATIVE', 'score': 0.9985740184783936}]
# {'score': 0.056833699345588684, 'start': 2231, 'end': 2311, 'answer': 'it will have a negative impact on the stock prices of existing leading companies'}
# [{'label': 'NEGATIVE', 'score': 0.9993938207626343}]
# {'score': 0.125862717628479, 'start': 625, 'end': 674, 'answer': '27 companies have been listed on the stock market'}
# [{'label': 'POSITIVE', 'score': 0.9822940826416016}]

# %%
score = []
for i in data:
    if i[0]['label'] == 'NEGATIVE':
        score.append(-i[0]['score'])
    else:
        score.append(i[0]['score'])

len(score)
# Out:
# 442

# %%
date_score = pd.DataFrame()
date_score['date'] = date
date_score['date'] = pd.to_datetime(date_score['date'],format='%Y-%m-%d')


date_score['score'] = score

resampled_week = pd.DataFrame(date_score.resample(rule='1W', on='date'))

temp = []
for i in range(len(resampled_week)):
    temp.append(resampled_week[1][i].mean().score)

week_mean = pd.DataFrame(temp)
# Out:
# /var/folders/4l/84htqxwn14n0jr_xvdc4tpbr0000gn/T/ipykernel_5728/1042392469.py:12: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp.append(resampled_week[1][i].mean().score)

# %%
question_tbl = pd.DataFrame()

# %%
#question_tbl['question1'] = week_mean # 'Will the stock price of cacao go up?'
#question_tbl['question2'] = week_mean # 'Is cacao growing?'
question_tbl['question3'] = week_mean # 'Is cacao growing?'

question_tbl
# Out:
#     question2  question1  question3
# 0    0.420655  -0.501771  -0.503562
# 1    0.265869   0.496300   0.715384
# 2    0.598848   0.406858   0.454324
# 3   -0.115972  -0.170329  -0.176874
# 4    0.429637   0.164453   0.707713
# 5    0.999013   0.985687   0.986117
# 6    0.990227   0.990395   0.924912
# 7    0.623333   0.217349   0.319667
# 8    0.681961   0.342514   0.802863
# 9    0.555210   0.072171  -0.198102
# 10   0.243510   0.566473   0.530113
# 11   0.394565   0.004895  -0.067124
# 12   0.536189   0.355833   0.369315
# 13   0.146545  -0.214370  -0.130760
# 14   0.819202  -0.097937   0.097263
# 15   0.260575   0.060973   0.031633
# 16  -0.234140   0.243508   0.224889
# 17   0.603169  -0.267380  -0.189515
# 18   0.327006   0.002338  -0.170604
# 19  -0.005854  -0.515210  -0.368157
# 20  -0.475191  -0.448654  -0.301307
# 21  -0.315546  -0.154831  -0.338860
# 22   0.201932  -0.556237  -0.157550
# 23   0.468177   0.414011  -0.496845
# 24   0.009835  -0.150866  -0.165329
# 25   0.259094  -0.201187  -0.201224
# 26  -0.084075  -0.709349  -0.470825
# 27   0.446921   0.299833   0.706255
# 28   0.142170   0.694255   0.083255
# 29   0.709354   0.141463  -0.129196
# 30   0.804887   0.021887   0.159554
# 31  -0.974633  -0.989331   0.001923
# 32   0.250030   0.707041   0.708009
# 33   0.999214   0.323396   0.332379
# 34   0.332366  -0.414647   0.580336
# 35   0.747693   0.330750  -0.571531
# 36  -0.200793   0.156886   0.199558
# 37   0.154195  -0.184998  -0.337398
# 38   0.368280  -0.374556   0.217795
# 39  -0.407569  -0.998525  -0.990082
# 40   0.199707   0.197754  -0.602383
# 41   0.504164  -0.262996  -0.248944
# 42   0.609662   0.217097   0.566670
# 43   0.092411   0.665364   0.016351
# 44  -0.987714  -0.967504  -0.000087
# 45   0.306338   0.329933  -0.002717
# 46   0.704642  -0.713057  -0.180946
# 47   0.341967   0.328694  -0.003139
# 48   0.366714   0.435885   0.263405
# 49   0.428577   0.183614   0.377921
# 50   0.392743   0.142498  -0.152163
# 51   0.293315   0.982430   0.324276
# 52  -0.003483  -0.999002  -0.002185

# %%
split_score_df = week_mean
split_span = 10
split_list = []

for i in range(len(split_score_df)-split_span):
    split_list.append(split_score_df[i:i+split_span].mean())

# %%
plt.plot(split_list)

# %%
plt.plot(week_price_mean['Close'][split_span:])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

lr = LinearRegression()
quad = PolynomialFeatures(degree=1) # ,include_bias=False
input_idx = len(sub_df) - 1

features = ['question1','question2','question3']

X = sub_df.loc[:,features]
y = week_price_mean['Close'][split_span:]
X_quad = quad.fit_transform(X)
lr.fit(X_quad,y)
y_quad_fit = lr.predict(quad.fit_transform(X))

pred = []
for i in y_quad_fit:
    if i < 0:
        pred.append(0)
    else:
        pred.append(i)

from sklearn.linear_model import ElasticNet
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(pred,y)
rmse = np.sqrt(mse)
print(rmse)
print(r2_score(pred,y)) # 1에 가까울수록 강한 상관관계, 0일 수록 관계없음
print(1-(1-r2_score(pred,y))*(input_idx-1)/(input_idx-len(features)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4l/84htqxwn14n0jr_xvdc4tpbr0000gn/T/ipykernel_5728/2765067597.py in <module>
#       4 lr = LinearRegression()
#       5 quad = PolynomialFeatures(degree=1) # ,include_bias=False
# ----> 6 input_idx = len(sub_df) - 1
#       7
#       8 features = ['question1','question2','question3']
#
# NameError: name 'sub_df' is not defined
