# %%
import pandas as pd
beigebook = pd.read_csv('/Users/junho/Desktop/main/big_data/lecture/week14/beigebook2002-2022.csv')
testimony = pd.read_csv('/Users/junho/Desktop/main/big_data/lecture/week14/testimony2009-2022.csv')
# from transformers import pipeline
# qa = pipeline('question-answering')

# qa(question='Will interest rates rise?',context=testimony.iloc[0,1])


import nltk
nltk.__version__
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
stopwords = set(stopwords.words('english'))
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
for book in beigebook.iloc[:,1]:
# Out:
# 0      Prepared at the Federal Reserve Bank of Dallas...
# 1      Prepared at the Federal Reserve Bank of Boston...
# 2      Prepared at the Federal Reserve Bank of Kansas...
# 3      Prepared at the Federal Reserve Bank of Atlant...
# 4      Prepared at the Federal Reserve Bank of New Yo...
#                              ...
# 156    Summary of Commentary on Current Economic Cond...
# 157    Summary of Commentary on Current Economic Cond...
# 158    Summary of Commentary on Current Economic Cond...
# 159    Summary of Commentary on Current Economic Cond...
# 160    Summary of Commentary on Current Economic Cond...
# Name: beige_book, Length: 161, dtype: object

# %%
all_words_df = pd.DataFrame(data=all_words)
df = pd.DataFrame(all_words_df.value_counts())

# %%
list(df.index)
# Out:
# [(',',),
#  ('.',),
#  ('in',),
#  ('and',),
#  ('the',),
#  ('Districts',),
#  ('of',),
#  ('reported',),
#  ('to',),
#  ('that',),
#  ('were',),
#  ('a',),
#  ('Dallas',),
#  ('for',),
#  ('activity',),
#  ('City',),
#  ('Kansas',),
#  ('District',),
#  ('Cleveland',),
#  ('noted',),
#  ('was',),
#  ('sales',),
#  ('Atlanta',),
#  ('Chicago',),
#  ('San',),
#  ('Francisco',),
#  ('Richmond',),
#  ('Philadelphia',),
#  ('Louis',),
#  ('St.',),
#  ('New',),
#  ('York',),
#  ('Minneapolis',),
#  ('Boston',),
#  ('on',),
#  ('while',),
#  ('demand',),
#  ('as',),
#  ('with',),
#  ('growth',),
#  ('The',),
#  ('or',),
#  ('prices',),
#  ('some',),
#  ('increased',),
#  ('continued',),
#  ('strong',),
#  ('contacts',),
#  ('most',),
#  ('but',),
#  ('at',),
#  ('mixed',),
#  ('increases',),
#  ('from',),
#  ('remained',),
#  ('construction',),
#  ('modest',),
#  ('services',),
#  ('by',),
#  ('generally',),
#  ('reporting',),
#  ('conditions',),
#  ('In',),
#  ('levels',),
# ...

# %%
temp = [list(i) for i in df.index]
word = [i[0] for i in temp]
word
# Out:
# [',',
#  '.',
#  'in',
#  'and',
#  'the',
#  'Districts',
#  'of',
#  'reported',
#  'to',
#  'that',
#  'were',
#  'a',
#  'Dallas',
#  'for',
#  'activity',
#  'City',
#  'Kansas',
#  'District',
#  'Cleveland',
#  'noted',
#  'was',
#  'sales',
#  'Atlanta',
#  'Chicago',
#  'San',
#  'Francisco',
#  'Richmond',
#  'Philadelphia',
#  'Louis',
#  'St.',
#  'New',
#  'York',
#  'Minneapolis',
#  'Boston',
#  'on',
#  'while',
#  'demand',
#  'as',
#  'with',
#  'growth',
#  'The',
#  'or',
#  'prices',
#  'some',
#  'increased',
#  'continued',
#  'strong',
#  'contacts',
#  'most',
#  'but',
#  'at',
#  'mixed',
#  'increases',
#  'from',
#  'remained',
#  'construction',
#  'modest',
#  'services',
#  'by',
#  'generally',
#  'reporting',
#  'conditions',
#  'In',
#  'levels',
#  'across',
#  'reports',
#  'indicated',
#  'firms',
#  'estate',
#  'slightly',
#  'real',
#  'said',
#  'have',
#  'moderate',
#  'production',
#  'Reserve',
#  'year',
#  'steady',
#  'Federal',
# ...

# %%
count = list(df.iloc[:,0])
count
# Out:
# [28822,
#  18773,
#  17386,
#  17369,
#  12874,
#  6959,
#  5897,
#  5881,
#  5666,
#  4785,
#  4377,
#  4049,
#  3816,
#  3639,
#  3334,
#  3326,
#  3321,
#  3219,
#  3193,
#  3124,
#  3024,
#  2991,
#  2938,
#  2901,
#  2901,
#  2900,
#  2882,
#  2807,
#  2633,
#  2626,
#  2580,
#  2468,
#  2374,
#  2271,
#  2206,
#  2169,
#  2102,
#  1899,
#  1886,
#  1858,
#  1750,
#  1720,
#  1678,
#  1615,
#  1602,
#  1583,
#  1550,
#  1519,
#  1501,
#  1479,
#  1414,
#  1412,
#  1375,
#  1320,
#  1283,
#  1196,
#  1137,
#  1104,
#  1013,
#  1011,
#  999,
#  994,
#  979,
#  965,
#  932,
#  918,
#  896,
#  871,
#  847,
#  838,
#  837,
#  820,
#  799,
#  794,
#  777,
#  775,
#  768,
#  766,
#  765,
#  764,
#  736,
#  692,
#  684,
#  678,
#  678,
#  674,
#  671,
#  667,
#  648,
#  632,
#  626,
#  624,
#  619,
#  614,
#  603,
#  602,
#  600,
#  591,
#  590,
#  589,
#  584,
#  583,
#  582,
#  575,
#  574,
#  569,
#  566,
#  563,
#  562,
#  556,
#  549,
#  549,
#  549,
#  548,
#  546,
#  523,
# ...

# %%
word_count = {}
for i in range(len(word)):
    if word[i] in stopwords:
        pass
    else:
        word_count[word[i]] = count[i]
word_count
# Out:
# {',': 28822,
#  '.': 18773,
#  'Districts': 6959,
#  'reported': 5881,
#  'Dallas': 3816,
#  'activity': 3334,
#  'City': 3326,
#  'Kansas': 3321,
#  'District': 3219,
#  'Cleveland': 3193,
#  'noted': 3124,
#  'sales': 2991,
#  'Atlanta': 2938,
#  'Chicago': 2901,
#  'San': 2901,
#  'Francisco': 2900,
#  'Richmond': 2882,
#  'Philadelphia': 2807,
#  'Louis': 2633,
#  'St.': 2626,
#  'New': 2580,
#  'York': 2468,
#  'Minneapolis': 2374,
#  'Boston': 2271,
#  'demand': 2102,
#  'growth': 1858,
#  'The': 1750,
#  'prices': 1678,
#  'increased': 1602,
#  'continued': 1583,
#  'strong': 1550,
#  'contacts': 1519,
#  'mixed': 1412,
#  'increases': 1375,
#  'remained': 1283,
#  'construction': 1196,
#  'modest': 1137,
#  'services': 1104,
#  'generally': 1011,
#  'reporting': 999,
#  'conditions': 994,
#  'In': 979,
#  'levels': 965,
#  'across': 932,
#  'reports': 918,
#  'indicated': 896,
#  'firms': 871,
#  'estate': 847,
#  'slightly': 838,
#  'real': 837,
#  'said': 820,
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer()
tf.fit(beigebook.iloc[:,1])
# Out:
# TfidfVectorizer()

# %%
tf.vocabulary_
# Out:
# {'prepared': 3020,
#  'at': 331,
#  'the': 4145,
#  'federal': 1575,
#  'reserve': 3412,
#  'bank': 392,
#  'of': 2674,
#  'dallas': 1005,
#  'and': 232,
#  'based': 411,
#  'on': 2694,
#  'information': 2047,
#  'collected': 747,
#  'before': 429,
#  'january': 2133,
#  '2002': 21,
#  'this': 4165,
#  'document': 1215,
#  'summarizes': 4042,
#  'comments': 764,
#  'received': 3248,
#  'from': 1713,
#  'business': 570,
#  'other': 2743,
#  'contacts': 874,
#  'outside': 2775,
#  'is': 2120,
#  'not': 2622,
#  'commentary': 761,
#  'views': 4434,
#  'officials': 2683,
#  'reports': 3395,
#  'districts': 1209,
#  'suggest': 4035,
#  'that': 4144,
#  'economic': 1302,
#  'activity': 117,
#  'generally': 1756,
#  'remained': 3354,
#  'weak': 4486,
#  'late': 2184,
#  'november': 2637,
#  'through': 4174,
#  'early': 1287,
#  'but': 573,
#  'while': 4518,
#  'there': 4154,
#  'are': 298,
#  'still': 3950,
#  'indications': 2030,
#  'caution': 633,
#  'also': 210,
#  'scattered': 3592,
# ...

# %%
tf.vocabulary_.keys()
# Out:
# dict_keys(['prepared', 'at', 'the', 'federal', 'reserve', 'bank', 'of', 'dallas', 'and', 'based', 'on', 'information', 'collected', 'before', 'january', '2002', 'this', 'document', 'summarizes', 'comments', 'received', 'from', 'business', 'other', 'contacts', 'outside', 'is', 'not', 'commentary', 'views', 'officials', 'reports', 'districts', 'suggest', 'that', 'economic', 'activity', 'generally', 'remained', 'weak', 'late', 'november', 'through', 'early', 'but', 'while', 'there', 'are', 'still', 'indications', 'caution', 'also', 'scattered', 'improvement', 'san', 'francisco', 'report', 'continued', 'decline', 'in', 'cleveland', 'district', 'indicates', 'regional', 'economy', 'appears', 'to', 'be', 'process', 'bottoming', 'out', 'slow', 'or', 'boston', 'chicago', 'philadelphia', 'kansas', 'city', 'st', 'louis', 'was', 'mixed', 'according', 'atlanta', 'minneapolis', 'richmond', 'showed', 'further', 'signs', 'rebounding', 'new', 'york', 'many', 'indicate', 'their', 'believe', 'recovery'
# ...
